# %% [markdown]
# <a href="https://colab.research.google.com/github/chaosmaker10/MultipleLinearRegression/blob/main/MultipleLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_set=pd.read_csv("Covid_data.csv")
data_set=pd.DataFrame(data_set)
X=data_set.iloc[:,:-1].values
y=data_set.iloc[:,-1].values
print(data_set)
# Out:
#     age Body Temp  Chronic disease  Blood O2 Level in Percentage  Anti Bodies
# 0    10  Moderate                0                            97       127181
# 1    80      High                0                            92        61004
# 2    10       Low                0                            97       111911
# 3    81      High                4                            75        39010
# 4    12  Moderate                0                            97       110911
# ..  ...       ...              ...                           ...          ...
# 65   76      High                4                            80        39010
# 66   35  Moderate                0                            92        91141
# 67   13  Moderate                0                            94       112101
# 68   82      High                3                            73        42010
# 69   84      High                3                            75        42099
#
# [70 rows x 5 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[1])],remainder='passthrough')
X=ct.fit_transform(X)
print(X)
# Out:
# [[0.0 0.0 1.0 10 0 97]
#  [1.0 0.0 0.0 80 0 92]
#  [0.0 1.0 0.0 10 0 97]
#  [1.0 0.0 0.0 81 4 75]
#  [0.0 0.0 1.0 12 0 97]
#  [0.0 1.0 0.0 18 0 66]
#  [0.0 0.0 1.0 13 0 93]
#  [1.0 0.0 0.0 94 4 64]
#  [1.0 0.0 0.0 86 2 76]
#  [0.0 0.0 1.0 20 0 92]
#  [0.0 0.0 1.0 15 0 94]
#  [0.0 0.0 1.0 15 0 92]
#  [0.0 1.0 0.0 16 0 92]
#  [0.0 0.0 1.0 17 0 93]
#  [0.0 0.0 1.0 18 0 93]
#  [0.0 0.0 1.0 19 0 92]
#  [0.0 0.0 1.0 19 0 89]
#  [0.0 0.0 1.0 12 0 97]
#  [0.0 0.0 1.0 20 0 93]
#  [0.0 0.0 1.0 24 0 92]
#  [0.0 0.0 1.0 25 0 93]
#  [1.0 0.0 0.0 59 2 68]
#  [1.0 0.0 0.0 63 1 66]
#  [0.0 0.0 1.0 25 1 62]
#  [1.0 0.0 0.0 26 0 94]
#  [0.0 1.0 0.0 26 0 97]
#  [0.0 0.0 1.0 28 0 99]
#  [1.0 0.0 0.0 59 0 69]
#  [0.0 0.0 1.0 28 0 89]
#  [0.0 0.0 1.0 29 0 93]
#  [0.0 0.0 1.0 48 0 93]
#  [0.0 0.0 1.0 30 0 62]
#  [0.0 0.0 1.0 30 0 86]
#  [0.0 0.0 1.0 32 0 84]
#  [0.0 0.0 1.0 34 1 90]
#  [0.0 0.0 1.0 35 0 89]
#  [1.0 0.0 0.0 50 2 77]
#  [1.0 0.0 0.0 56 2 76]
#  [1.0 0.0 0.0 56 1 77]
#  [1.0 0.0 0.0 36 1 90]
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=12)
print(X_train)
# Out:
# [[1.0 0.0 0.0 62 2 69]
#  [0.0 0.0 1.0 19 0 92]
#  [1.0 0.0 0.0 26 0 94]
#  [1.0 0.0 0.0 42 0 92]
#  [1.0 0.0 0.0 76 4 80]
#  [1.0 0.0 0.0 84 3 75]
#  [1.0 0.0 0.0 40 0 92]
#  [1.0 0.0 0.0 61 2 76]
#  [0.0 0.0 1.0 20 0 92]
#  [1.0 0.0 0.0 82 3 73]
#  [0.0 0.0 1.0 25 0 93]
#  [0.0 0.0 1.0 19 0 89]
#  [1.0 0.0 0.0 75 1 72]
#  [1.0 0.0 0.0 74 2 75]
#  [0.0 0.0 1.0 30 0 86]
#  [0.0 0.0 1.0 48 0 93]
#  [0.0 0.0 1.0 32 0 84]
#  [1.0 0.0 0.0 52 1 80]
#  [1.0 0.0 0.0 50 2 77]
#  [0.0 0.0 1.0 35 0 89]
#  [1.0 0.0 0.0 64 1 73]
#  [0.0 0.0 1.0 20 0 93]
#  [1.0 0.0 0.0 68 1 67]
#  [0.0 1.0 0.0 16 0 92]
#  [1.0 0.0 0.0 38 2 75]
#  [1.0 0.0 0.0 58 0 70]
#  [0.0 0.0 1.0 10 0 97]
#  [0.0 0.0 1.0 15 0 94]
#  [1.0 0.0 0.0 60 1 68]
#  [0.0 0.0 1.0 15 0 92]
#  [0.0 0.0 1.0 34 1 90]
#  [0.0 1.0 0.0 26 0 97]
#  [0.0 0.0 1.0 17 0 93]
#  [0.0 1.0 0.0 18 0 66]
#  [1.0 0.0 0.0 78 2 71]
#  [1.0 0.0 0.0 53 1 55]
#  [1.0 0.0 0.0 63 1 66]
#  [0.0 0.0 1.0 32 0 89]
#  [1.0 0.0 0.0 81 4 75]
#  [0.0 1.0 0.0 10 0 97]
# ...

# %%
# plt.scatter(X_train,y_train)
plt.plot(X_train,y_train)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)
plt.plot(y_pred)
plt.plot(y_test)

# %%
# y_test.as_type('int64')
print(y_test)
print(y_pred)
# Out:
# [ 95202  61002  45019  37914  90191 112101  91141  61082  77010  60801
#   71191  78010  99004  92101 110911  87019  75012  67010  59913  46016
#   41891  93010  93091  61018 110911  84008  61004  67019]
# [ 98231.36891939  58543.17724358  45016.71028513  27936.14680003
#   85598.44392823 105929.62286124  91364.97018721  66043.96663334
#   77634.78599727  63743.25228198  74303.44524692  81581.47886038
#  102392.6049236   95526.20619142 107801.62374232  87412.02464472
#   82008.23237484  67707.02373409  53157.77019991  35228.64572806
#   39389.22841367  98645.98988701  94486.71383862  60218.36689116
#  107801.62374232  83320.03471472  62512.54805646  64305.78359092]
